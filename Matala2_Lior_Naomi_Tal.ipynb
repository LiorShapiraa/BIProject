# %%
# !pip install jsonpath_ng
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: jsonpath_ng in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: ply in /usr/local/lib/python3.10/dist-packages (from jsonpath_ng) (3.11)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from jsonpath_ng) (4.4.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from jsonpath_ng) (1.16.0)

# %%
import os
import csv
import json
import numpy as np 
import pandas as pd 
import sqlite3
import functools as ft
import matplotlib.pyplot as plt
from abc import ABC, abstractmethod
from jsonpath_ng import parse
from enum import Enum
# %matplotlib inline

# %% [markdown]
# ### Source to Target Mapping - OOP Approach for Single Table

# %% [markdown]
# Data

# %%
with open("factTableShorter.csv", "r", encoding="utf-8-sig") as file:
    data = list(csv.DictReader(file))
    for item in data:
        item["TotalPrice"] =str(item["TotalPrice"])
data[:10]
# Out:
# [{'TransactionNo': '581482', 'CustomerNo': '17490', 'TotalPrice': '257.64'},
#  {'TransactionNo': '581475', 'CustomerNo': '13069', 'TotalPrice': '383.4'},
#  {'TransactionNo': '581475', 'CustomerNo': '13069', 'TotalPrice': '138.36'},
#  {'TransactionNo': '581475', 'CustomerNo': '13069', 'TotalPrice': '127.8'},
#  {'TransactionNo': '581475', 'CustomerNo': '13069', 'TotalPrice': '71.64'},
#  {'TransactionNo': '581475', 'CustomerNo': '13069', 'TotalPrice': '255.6'},
#  {'TransactionNo': '581475', 'CustomerNo': '13069', 'TotalPrice': '207.54'},
#  {'TransactionNo': '581475', 'CustomerNo': '13069', 'TotalPrice': '147'},
#  {'TransactionNo': '581475', 'CustomerNo': '13069', 'TotalPrice': '127.8'},
#  {'TransactionNo': '581475', 'CustomerNo': '13069', 'TotalPrice': '253.2'}]

# %% [markdown]
# ###  Abstract Base Calss (ABC) for mutual methods

# %%
class Interface(ABC):

    @abstractmethod
    def get_data_by_field(self, field_name):
        """Fetch the data by given feild name """

    @abstractmethod
    def get_data_by_id(self, id):
        """Fetch the data by given ID  """

    @abstractmethod
    def get(self):
        """Fetch all data """

# %% [markdown]
# ### Transform Operations
# inherithed from Enum - class that automatic enumrate the variables

# %%
class TransformMask(Enum):
    # add here any masks you want 
    CLEAN_STRING = ".strip().lower()" 
    CAPITAL_LETTER = ".strip().lower().title()"

# %% [markdown]
# Database Class - Define Common Properties for Source, Target, Mapping

# %%
class Database:
    def __init__(self):
        self.db = {
            "source": [],
            "destination": [],
            "transform": [],
            "mapping": []
        }
        self.add_source(1,"TransactionNo","$.TransactionNo","str",True)
        self.add_source(2,"CustomerNo","$.CustomerNo","str",True)
        self.add_source(3,"TotalPrice","$.TotalPrice","str",True)
        self.add_destination(1,"TransactionNo","TransactionNo","str","n/a")
        self.add_destination(2,"CustomerNo","CustomerNo","str","n/a")
        self.add_destination(3,"TotalPrice","TotalPrice","float","0")
        self.add_transform(1,'CLEAN_STRING')
        self.add_mapping(1,1,1,1)
        self.add_mapping(2,2,2,1)
        self.add_mapping(3,3,3)

    def add_source(self,id,source_field_name,source_field_mapping,source_field_type,is_required):
      if source_field_type not in ["str", "float", "list", "int", "set", "dict"]:
        print("Error")
      if not isinstance(is_required, bool):
        print("Error")
      else:
        source = {
            "id": id,
            "source_field_name": source_field_name,
            "source_field_mapping": source_field_mapping,
            "source_field_type": source_field_type,
            "is_required": is_required
        }
        self.db["source"].append(source)
        
    def add_destination(self,id,destination_field_name,destination_field_mapping,destination_field_type,default_value):
      if destination_field_type not in ["str", "float", "list", "int", "set", "dict"]:
        print("Error")
      else:
        destination = {
              "id": id,
              "destination_field_name": destination_field_name,
              "destination_field_mapping": destination_field_mapping,
              "destination_field_type": destination_field_type,
              "default_value": default_value
          }
        self.db["destination"].append(destination)

    def add_transform(self,id,transform_mask):
      transform={
          "id": id,
          "transform_mask": transform_mask
      }
      self.db["transform"].append(transform)

    def add_mapping(self,id,mapping_source,mapping_destination,mapping_transform=None):
      if mapping_transform is not None:
        mapping={
          "id": id,
          "mapping_source": mapping_source,
          "mapping_destination": mapping_destination,
          "mapping_transform": mapping_transform
        }
      else:
        mapping={
          "id": id,
          "mapping_source": mapping_source,
          "mapping_destination": mapping_destination
          }
      self.db["mapping"].append(mapping)

    @property 
    def get_data_source_target_mapping(self):
        return self.db

# %% [markdown]
# ## **Source class**
# Inherited from Interface for the common methods and from Database for common variables

# %%
class Source(Interface, Database):
    def __init__(self):
        Database.__init__(self)

    # should be implemented - inherited from Interface
    def get_data_by_field(self, field_name):
        data = self.get
        for item in data:
            for key, value in item.items():
                if key == field_name:
                    return item
        return None

    @property
    def get(self):
        return self.get_data_source_target_mapping.get("source")

    def get_data_by_id(self, id):
        self.id = id
        data = self.get
        for x in data:
            if x.get("id") == self.id:
                return x
        return None

# %% [markdown]
# ## **Target class**
# Inherited from Interface for the common methods and from Database for common variables

# %%
class Target(Interface, Database):

    def __init__(self):
        Database.__init__(self)

    # should be implemented - inherited from Interface
    def get_data_by_field(self, field_name):
        data = self.get
        for item in data:
            for key, value in item.items():
                if key == field_name:
                    return item
        return None

    @property
    def get(self):
        return self.get_data_source_target_mapping.get("destination")

    def get_data_by_id(self, id):
        self.id = id
        data = self.get
        for x in data:
            if x.get("id").__str__() == self.id.__str__():
                return x
        return None

# %% [markdown]
# ## **Transform Class**
# Inherited from Interface for the common methods and from Database for common variables

# %%
class Transform(Interface, Database):

    def __init__(self):
        Database.__init__(self)

    # should be implemented - inherited from Interface
    def get_data_by_field(self, field_name):
        data = self.get
        for item in data:
            for key, value in item.items():
                if key == field_name:
                    return item
        return None

    @property
    def get(self):
        return self.get_data_source_target_mapping.get("transform", [])

    def get_data_by_id(self, id):
        self.id = id
        data = self.get
        for x in data:
            if x.get("id").__str__() == self.id.__str__():
                return x
        return None

# %% [markdown]
# ## **Mapping class**
# Inherited from Interface for the common methods and from Database for common variables

# %%
class Mappings(Interface, Database):

    def __init__(self):
        Database.__init__(self)

    @property
    def get(self):
        return self.get_data_source_target_mapping.get("mapping")

    def get_data_by_id(self, id):
        self.id = id
        data = self.get
        for x in data:
            if x.get("id").__str__() == self.id.__str__():
                return x
        return None

    def get_data_by_field(self, field_name):
        return None

# %% [markdown]
# ### Format Class - JSON
#
# Search the source data value inside a JSON file

# %%
class JsonQuery:
    def __init__(self, json_path, json_data):
        self.json_path = json_path
        self.json_data = json_data

    def get(self):
        jsonpath_expression = parse(self.json_path)
        match = jsonpath_expression.find(self.json_data)
        source_data_value = match[0].value
        return source_data_value

# %% [markdown]
# ### Combine it All - STTM

# %%
class STTM:
    def __init__(self, input_json):
        self.input_json = input_json
        self.mapping_instance = Mappings()
        self.source_instance = Source()
        self.destination_instance = Target()
        self.transform_instance = Transform()
        self.look_up_mask = {i.name: i.value for i in TransformMask}
        self.json_data_transformed = {}

    def _get_mapping_data(self):
        return self.mapping_instance.get

    def _get_mapping_source_data(self):
        return self.source_instance.get

    def get_transformed_data(self):

        for mappings in self._get_mapping_data():

            """fetch the source mapping """
            mapping_source_id = mappings.get("mapping_source")
            mapping_destination_id = mappings.get("mapping_destination")
            mapping_transform_id = mappings.get("mapping_transform")

            mapping_source_data = self.source_instance.get_data_by_id(id=mapping_source_id)
            transform_data = self.transform_instance.get_data_by_id(id=mapping_transform_id)

            """Fetch Source  field Name"""
            source_field_name = mapping_source_data.get("source_field_name")

            """if field given is not present incoming json """
            if source_field_name not in self.input_json.keys():
                if mapping_source_data.get("is_required"):
                    raise Exception(
                        "Alert ! Field {} is not present in JSON please FIX mappings ".format(source_field_name))
                else:
                    pass

            else:
                source_data_value = JsonQuery(
                    json_path=mapping_source_data.get("source_field_mapping"),
                    json_data=self.input_json
                ).get()

                """check the data type for source if matches with what we have """
                if mapping_source_data.get("source_field_type") != type(source_data_value).__name__:
                    if source_data_value is not None:
                        _message = (
                            "Alert ! Source Field :{} Datatype has changed from {} to {} ".format(source_field_name,
                                                                                                  mapping_source_data.get(
                                                                                                      "source_field_type"),
                                                                                                  type(
                                                                                                      source_data_value).__name__))
                        print(_message)
                        raise Exception(_message)

                """Query and fetch the Destination | target """
                destination_mappings_json_object = self.destination_instance.get_data_by_id(
                    id=mappings.get("mapping_destination"))
               # print(mappings.get("mapping_destination"))
                destination_field_name = destination_mappings_json_object.get("destination_field_name")
                destination_field_type = destination_mappings_json_object.get("destination_field_type")

                dtypes = [str, float, list, int, set, dict]

                for dtype in dtypes:

                    """Datatype Conversion """
                    if destination_field_type == str(dtype.__name__):

                        """is source is none insert default value"""
                        if source_data_value is None:
                            self.json_data_transformed[destination_field_name] = dtype.__call__(
                                destination_mappings_json_object.get("default_value")
                            )

                        else:
                            """check if you have items to transform"""
                            if transform_data is not None:
                                """ check for invalid mask name """
                                if transform_data.get("transform_mask") not in list(self.look_up_mask.keys()):
                                    raise Exception(
                                        f"Specified Transform {transform_data.get('transform_mask')} is not available please select from following Options :{list(self.look_up_mask.keys())}")
                                else:
                                    mask_apply = self.look_up_mask.get(transform_data.get("transform_mask"))
                                    converted_dtype = dtype.__call__(source_data_value)
                                    mask = f'converted_dtype{mask_apply}'
                                    curated_value = eval(mask)
                                    self.json_data_transformed[destination_field_name] = curated_value

                            else:
                                self.json_data_transformed[destination_field_name] = dtype.__call__(source_data_value)

        return self.json_data_transformed

# %%
transformed_data = []
for item in data:
    helper = STTM(input_json=item)
    response = helper.get_transformed_data()
    transformed_data.append(response)
    print(response)
# Out:
# Streaming output truncated to the last 5000 lines.
# {'TransactionNo': '580680', 'CustomerNo': '13001', 'TotalPrice': 21.72}
# {'TransactionNo': '580680', 'CustomerNo': '13001', 'TotalPrice': 43.44}
# {'TransactionNo': '580680', 'CustomerNo': '13001', 'TotalPrice': 1390.08}
# {'TransactionNo': '580680', 'CustomerNo': '13001', 'TotalPrice': 21.72}
# {'TransactionNo': '580680', 'CustomerNo': '13001', 'TotalPrice': 144.8}
# {'TransactionNo': '580680', 'CustomerNo': '13001', 'TotalPrice': 86.88}
# {'TransactionNo': '580680', 'CustomerNo': '13001', 'TotalPrice': 86.88}
# {'TransactionNo': '580680', 'CustomerNo': '13001', 'TotalPrice': 43.44}
# {'TransactionNo': '580680', 'CustomerNo': '13001', 'TotalPrice': 45.96}
# {'TransactionNo': '580680', 'CustomerNo': '13001', 'TotalPrice': 91.92}
# {'TransactionNo': '580680', 'CustomerNo': '13001', 'TotalPrice': 22.98}
# {'TransactionNo': '580680', 'CustomerNo': '13001', 'TotalPrice': 24.52}
# {'TransactionNo': '580680', 'CustomerNo': '13001', 'TotalPrice': 24.52}
# {'TransactionNo': '580680', 'CustomerNo': '13001', 'TotalPrice': 72.4}
# {'TransactionNo': '580681', 'CustomerNo': '13083', 'TotalPrice': 49.04}
# {'TransactionNo': '580681', 'CustomerNo': '13083', 'TotalPrice': 49.04}
# {'TransactionNo': '580681', 'CustomerNo': '13083', 'TotalPrice': 24.52}
# {'TransactionNo': '580681', 'CustomerNo': '13083', 'TotalPrice': 147.12}
# {'TransactionNo': '580682', 'CustomerNo': '16968', 'TotalPrice': 49.04}
# {'TransactionNo': '580682', 'CustomerNo': '16968', 'TotalPrice': 73.56}
# {'TransactionNo': '580682', 'CustomerNo': '16968', 'TotalPrice': 49.04}
# {'TransactionNo': '580682', 'CustomerNo': '16968', 'TotalPrice': 147.12}
# {'TransactionNo': '580682', 'CustomerNo': '16968', 'TotalPrice': 147.12}
# {'TransactionNo': '580682', 'CustomerNo': '16968', 'TotalPrice': 98.08}
# {'TransactionNo': '580682', 'CustomerNo': '16968', 'TotalPrice': 147.12}
# {'TransactionNo': '580682', 'CustomerNo': '16968', 'TotalPrice': 98.08}
# {'TransactionNo': '580682', 'CustomerNo': '16968', 'TotalPrice': 110.34}
# {'TransactionNo': '580682', 'CustomerNo': '16968', 'TotalPrice': 73.56}
# {'TransactionNo': '580682', 'CustomerNo': '16968', 'TotalPrice': 35.82}
# {'TransactionNo': '580682', 'CustomerNo': '16968', 'TotalPrice': 71.64}
# {'TransactionNo': '580682', 'CustomerNo': '16968', 'TotalPrice': 71.64}
# {'TransactionNo': '580682', 'CustomerNo': '16968', 'TotalPrice': 71.64}
# {'TransactionNo': '580682', 'CustomerNo': '16968', 'TotalPrice': 71.64}
# {'TransactionNo': '580682', 'CustomerNo': '16968', 'TotalPrice': 71.64}
# {'TransactionNo': '580683', 'CustomerNo': '17683', 'TotalPrice': 7.24}
# {'TransactionNo': '580683', 'CustomerNo': '17683', 'TotalPrice': 7.24}
# {'TransactionNo': '580684', 'CustomerNo': '13305', 'TotalPrice': 35.82}
# {'TransactionNo': '580684', 'CustomerNo': '13305', 'TotalPrice': 71.64}
# {'TransactionNo': '580684', 'CustomerNo': '13305', 'TotalPrice': 73.56}
# {'TransactionNo': '580684', 'CustomerNo': '13305', 'TotalPrice': 147.12}
# {'TransactionNo': '580684', 'CustomerNo': '13305', 'TotalPrice': 147.12}
# {'TransactionNo': '580684', 'CustomerNo': '13305', 'TotalPrice': 86.88}
# {'TransactionNo': '580684', 'CustomerNo': '13305', 'TotalPrice': 57.92}
# {'TransactionNo': '580684', 'CustomerNo': '13305', 'TotalPrice': 347.52}
# {'TransactionNo': '580684', 'CustomerNo': '13305', 'TotalPrice': 59.7}
# {'TransactionNo': '580685', 'CustomerNo': '17676', 'TotalPrice': 86.88}
# {'TransactionNo': '580685', 'CustomerNo': '17676', 'TotalPrice': 71.64}
# {'TransactionNo': '580685', 'CustomerNo': '17676', 'TotalPrice': 73.56}
# {'TransactionNo': '580685', 'CustomerNo': '17676', 'TotalPrice': 73.56}
# {'TransactionNo': '580685', 'CustomerNo': '17676', 'TotalPrice': 73.56}
# {'TransactionNo': '580685', 'CustomerNo': '17676', 'TotalPrice': 147.12}
# {'TransactionNo': '580685', 'CustomerNo': '17676', 'TotalPrice': 73.56}
# {'TransactionNo': '580685', 'CustomerNo': '17676', 'TotalPrice': 147.12}
# {'TransactionNo': '580685', 'CustomerNo': '17676', 'TotalPrice': 61.3}
# {'TransactionNo': '580685', 'CustomerNo': '17676', 'TotalPrice': 245.2}
# {'TransactionNo': '580685', 'CustomerNo': '17676', 'TotalPrice': 24.52}
# {'TransactionNo': '580685', 'CustomerNo': '17676', 'TotalPrice': 11.94}
# {'TransactionNo': '580685', 'CustomerNo': '17676', 'TotalPrice': 72.4}
# {'TransactionNo': '580685', 'CustomerNo': '17676', 'TotalPrice': 72.4}
# {'TransactionNo': '580685', 'CustomerNo': '17676', 'TotalPrice': 59.7}
# {'TransactionNo': '580685', 'CustomerNo': '17676', 'TotalPrice': 61.3}
# {'TransactionNo': '580687', 'CustomerNo': '16379', 'TotalPrice': 143.28}
# {'TransactionNo': '580687', 'CustomerNo': '16379', 'TotalPrice': 73.56}
# {'TransactionNo': '580687', 'CustomerNo': '16379', 'TotalPrice': 159.36}
# {'TransactionNo': '580687', 'CustomerNo': '16379', 'TotalPrice': 73.56}
# {'TransactionNo': '580687', 'CustomerNo': '16379', 'TotalPrice': 73.56}
# {'TransactionNo': '580687', 'CustomerNo': '16379', 'TotalPrice': 73.56}
# {'TransactionNo': '580687', 'CustomerNo': '16379', 'TotalPrice': 73.56}
# {'TransactionNo': '580687', 'CustomerNo': '16379', 'TotalPrice': 71.64}
# {'TransactionNo': '580687', 'CustomerNo': '16379', 'TotalPrice': 35.82}
# {'TransactionNo': '580687', 'CustomerNo': '16379', 'TotalPrice': 36.78}
# {'TransactionNo': '580687', 'CustomerNo': '16379', 'TotalPrice': 73.56}
# {'TransactionNo': '580687', 'CustomerNo': '16379', 'TotalPrice': 73.56}
# {'TransactionNo': '580687', 'CustomerNo': '16379', 'TotalPrice': 61.3}
# {'TransactionNo': '580687', 'CustomerNo': '16379', 'TotalPrice': 61.3}
# {'TransactionNo': '580687', 'CustomerNo': '16379', 'TotalPrice': 122.6}
# {'TransactionNo': '580687', 'CustomerNo': '16379', 'TotalPrice': 122.6}
# {'TransactionNo': '580687', 'CustomerNo': '16379', 'TotalPrice': 61.3}
# {'TransactionNo': '580688', 'CustomerNo': '15550', 'TotalPrice': 12.26}
# {'TransactionNo': '580688', 'CustomerNo': '15550', 'TotalPrice': 49.04}
# {'TransactionNo': '580688', 'CustomerNo': '15550', 'TotalPrice': 18.39}
# {'TransactionNo': '580688', 'CustomerNo': '15550', 'TotalPrice': 6.13}
# {'TransactionNo': '580688', 'CustomerNo': '15550', 'TotalPrice': 12.26}
# {'TransactionNo': '580688', 'CustomerNo': '15550', 'TotalPrice': 12.26}
# {'TransactionNo': '580688', 'CustomerNo': '15550', 'TotalPrice': 6.13}
# {'TransactionNo': '580688', 'CustomerNo': '15550', 'TotalPrice': 35.82}
# {'TransactionNo': '580688', 'CustomerNo': '15550', 'TotalPrice': 17.91}
# {'TransactionNo': '580688', 'CustomerNo': '15550', 'TotalPrice': 35.82}
# {'TransactionNo': '580688', 'CustomerNo': '15550', 'TotalPrice': 47.76}
# {'TransactionNo': '580688', 'CustomerNo': '15550', 'TotalPrice': 5.97}
# {'TransactionNo': '580689', 'CustomerNo': '12994', 'TotalPrice': 35.82}
# {'TransactionNo': '580689', 'CustomerNo': '12994', 'TotalPrice': 21.72}
# {'TransactionNo': '580689', 'CustomerNo': '12994', 'TotalPrice': 86.88}
# {'TransactionNo': '580689', 'CustomerNo': '12994', 'TotalPrice': 14.48}
# {'TransactionNo': '580689', 'CustomerNo': '12994', 'TotalPrice': 35.82}
# {'TransactionNo': '580689', 'CustomerNo': '12994', 'TotalPrice': 5.97}
# {'TransactionNo': '580689', 'CustomerNo': '12994', 'TotalPrice': 147.12}
# {'TransactionNo': '580689', 'CustomerNo': '12994', 'TotalPrice': 61.3}
# {'TransactionNo': '580689', 'CustomerNo': '12994', 'TotalPrice': 18.39}
# {'TransactionNo': '580689', 'CustomerNo': '12994', 'TotalPrice': 36.78}
# {'TransactionNo': '580689', 'CustomerNo': '12994', 'TotalPrice': 24.52}
# {'TransactionNo': '580689', 'CustomerNo': '12994', 'TotalPrice': 12.26}
# {'TransactionNo': '580689', 'CustomerNo': '12994', 'TotalPrice': 12.26}
# {'TransactionNo': '580689', 'CustomerNo': '12994', 'TotalPrice': 36.78}
# {'TransactionNo': '580689', 'CustomerNo': '12994', 'TotalPrice': 153.25}
# {'TransactionNo': '580689', 'CustomerNo': '12994', 'TotalPrice': 36.78}
# {'TransactionNo': '580689', 'CustomerNo': '12994', 'TotalPrice': 73.56}
# {'TransactionNo': '580689', 'CustomerNo': '12994', 'TotalPrice': 61.3}
# {'TransactionNo': '580689', 'CustomerNo': '12994', 'TotalPrice': 73.56}
# {'TransactionNo': '580689', 'CustomerNo': '12994', 'TotalPrice': 24.52}
# {'TransactionNo': '580690', 'CustomerNo': '16597', 'TotalPrice': 662.04}
# {'TransactionNo': '580690', 'CustomerNo': '16597', 'TotalPrice': 36.78}
# {'TransactionNo': '580690', 'CustomerNo': '16597', 'TotalPrice': 196.16}
# {'TransactionNo': '580690', 'CustomerNo': '16597', 'TotalPrice': 12.26}
# {'TransactionNo': '580690', 'CustomerNo': '16597', 'TotalPrice': 73.56}
# {'TransactionNo': '580690', 'CustomerNo': '16597', 'TotalPrice': 73.56}
# {'TransactionNo': '580690', 'CustomerNo': '16597', 'TotalPrice': 73.56}
# {'TransactionNo': '580691', 'CustomerNo': '13790', 'TotalPrice': 147.12}
# {'TransactionNo': '580691', 'CustomerNo': '13790', 'TotalPrice': 220.68}
# {'TransactionNo': '580691', 'CustomerNo': '13790', 'TotalPrice': 220.68}
# {'TransactionNo': '580691', 'CustomerNo': '13790', 'TotalPrice': 36.78}
# {'TransactionNo': '580691', 'CustomerNo': '13790', 'TotalPrice': 24.52}
# {'TransactionNo': '580691', 'CustomerNo': '13790', 'TotalPrice': 36.78}
# {'TransactionNo': '580691', 'CustomerNo': '13790', 'TotalPrice': 73.56}
# {'TransactionNo': '580691', 'CustomerNo': '13790', 'TotalPrice': 147.12}
# {'TransactionNo': '580691', 'CustomerNo': '13790', 'TotalPrice': 73.56}
# {'TransactionNo': '580691', 'CustomerNo': '13790', 'TotalPrice': 294.24}
# {'TransactionNo': '580691', 'CustomerNo': '13790', 'TotalPrice': 294.24}
# {'TransactionNo': '580691', 'CustomerNo': '13790', 'TotalPrice': 98.08}
# {'TransactionNo': '580691', 'CustomerNo': '13790', 'TotalPrice': 294.24}
# {'TransactionNo': '580691', 'CustomerNo': '13790', 'TotalPrice': 220.68}
# {'TransactionNo': '580691', 'CustomerNo': '13790', 'TotalPrice': 220.68}
# {'TransactionNo': '580691', 'CustomerNo': '13790', 'TotalPrice': 220.68}
# {'TransactionNo': '580691', 'CustomerNo': '13790', 'TotalPrice': 73.56}
# {'TransactionNo': '580691', 'CustomerNo': '13790', 'TotalPrice': 79.68}
# {'TransactionNo': '580691', 'CustomerNo': '13790', 'TotalPrice': 73.56}
# {'TransactionNo': '580691', 'CustomerNo': '13790', 'TotalPrice': 73.56}
# {'TransactionNo': '580691', 'CustomerNo': '13790', 'TotalPrice': 73.56}
# {'TransactionNo': '580691', 'CustomerNo': '13790', 'TotalPrice': 73.56}
# {'TransactionNo': '580691', 'CustomerNo': '13790', 'TotalPrice': 73.56}
# {'TransactionNo': '580691', 'CustomerNo': '13790', 'TotalPrice': 73.56}
# {'TransactionNo': '580691', 'CustomerNo': '13790', 'TotalPrice': 73.56}
# {'TransactionNo': '580691', 'CustomerNo': '13790', 'TotalPrice': 73.56}
# {'TransactionNo': '580691', 'CustomerNo': '13790', 'TotalPrice': 73.56}
# {'TransactionNo': '580691', 'CustomerNo': '13790', 'TotalPrice': 73.56}
# {'TransactionNo': '580691', 'CustomerNo': '13790', 'TotalPrice': 73.56}
# {'TransactionNo': '580691', 'CustomerNo': '13790', 'TotalPrice': 71.64}
# {'TransactionNo': '580691', 'CustomerNo': '13790', 'TotalPrice': 71.64}
# {'TransactionNo': '580691', 'CustomerNo': '13790', 'TotalPrice': 71.64}
# {'TransactionNo': '580691', 'CustomerNo': '13790', 'TotalPrice': 71.64}
# {'TransactionNo': '580691', 'CustomerNo': '13790', 'TotalPrice': 71.64}
# {'TransactionNo': '580691', 'CustomerNo': '13790', 'TotalPrice': 71.64}
# {'TransactionNo': '580691', 'CustomerNo': '13790', 'TotalPrice': 73.56}
# {'TransactionNo': '580691', 'CustomerNo': '13790', 'TotalPrice': 73.56}
# {'TransactionNo': '580691', 'CustomerNo': '13790', 'TotalPrice': 73.56}
# {'TransactionNo': '580691', 'CustomerNo': '13790', 'TotalPrice': 73.56}
# {'TransactionNo': '580691', 'CustomerNo': '13790', 'TotalPrice': 73.56}
# {'TransactionNo': '580691', 'CustomerNo': '13790', 'TotalPrice': 73.56}
# {'TransactionNo': '580691', 'CustomerNo': '13790', 'TotalPrice': 36.78}
# {'TransactionNo': '580691', 'CustomerNo': '13790', 'TotalPrice': 36.78}
# {'TransactionNo': '580691', 'CustomerNo': '13790', 'TotalPrice': 24.52}
# {'TransactionNo': '580691', 'CustomerNo': '13790', 'TotalPrice': 24.52}
# {'TransactionNo': '580692', 'CustomerNo': '13173', 'TotalPrice': 6.13}
# {'TransactionNo': '580692', 'CustomerNo': '13173', 'TotalPrice': 24.52}
# {'TransactionNo': '580692', 'CustomerNo': '13173', 'TotalPrice': 6.13}
# {'TransactionNo': '580692', 'CustomerNo': '13173', 'TotalPrice': 49.04}
# {'TransactionNo': '580692', 'CustomerNo': '13173', 'TotalPrice': 29.85}
# {'TransactionNo': '580692', 'CustomerNo': '13173', 'TotalPrice': 11.94}
# {'TransactionNo': '580692', 'CustomerNo': '13173', 'TotalPrice': 12.26}
# {'TransactionNo': '580692', 'CustomerNo': '13173', 'TotalPrice': 39.84}
# {'TransactionNo': '580692', 'CustomerNo': '13173', 'TotalPrice': 231.68}
# {'TransactionNo': '580692', 'CustomerNo': '13173', 'TotalPrice': 36.2}
# {'TransactionNo': '580692', 'CustomerNo': '13173', 'TotalPrice': 14.48}
# {'TransactionNo': '580692', 'CustomerNo': '13173', 'TotalPrice': 36.2}
# {'TransactionNo': '580692', 'CustomerNo': '13173', 'TotalPrice': 14.48}
# {'TransactionNo': '580692', 'CustomerNo': '13173', 'TotalPrice': 7.24}
# {'TransactionNo': '580692', 'CustomerNo': '13173', 'TotalPrice': 181.0}
# {'TransactionNo': '580692', 'CustomerNo': '13173', 'TotalPrice': 181.0}
# {'TransactionNo': '580692', 'CustomerNo': '13173', 'TotalPrice': 181.0}
# {'TransactionNo': '580692', 'CustomerNo': '13173', 'TotalPrice': 21.72}
# {'TransactionNo': '580692', 'CustomerNo': '13173', 'TotalPrice': 28.96}
# {'TransactionNo': '580692', 'CustomerNo': '13173', 'TotalPrice': 36.2}
# {'TransactionNo': '580693', 'CustomerNo': '15690', 'TotalPrice': 86.88}
# {'TransactionNo': '580693', 'CustomerNo': '15690', 'TotalPrice': 347.52}
# {'TransactionNo': '580693', 'CustomerNo': '15690', 'TotalPrice': 86.88}
# {'TransactionNo': '580693', 'CustomerNo': '15690', 'TotalPrice': 86.88}
# {'TransactionNo': '580693', 'CustomerNo': '15690', 'TotalPrice': 173.76}
# {'TransactionNo': '580693', 'CustomerNo': '15690', 'TotalPrice': 86.88}
# {'TransactionNo': '580693', 'CustomerNo': '15690', 'TotalPrice': 73.56}
# {'TransactionNo': '580693', 'CustomerNo': '15690', 'TotalPrice': 147.12}
# {'TransactionNo': '580693', 'CustomerNo': '15690', 'TotalPrice': 147.12}
# {'TransactionNo': '580693', 'CustomerNo': '15690', 'TotalPrice': 73.56}
# {'TransactionNo': '580693', 'CustomerNo': '15690', 'TotalPrice': 73.56}
# {'TransactionNo': '580694', 'CustomerNo': '16600', 'TotalPrice': 61.3}
# {'TransactionNo': '580694', 'CustomerNo': '16600', 'TotalPrice': 153.25}
# {'TransactionNo': '580694', 'CustomerNo': '16600', 'TotalPrice': 73.56}
# {'TransactionNo': '580694', 'CustomerNo': '16600', 'TotalPrice': 147.12}
# {'TransactionNo': '580694', 'CustomerNo': '16600', 'TotalPrice': 147.12}
# {'TransactionNo': '580694', 'CustomerNo': '16600', 'TotalPrice': 73.56}
# {'TransactionNo': '580694', 'CustomerNo': '16600', 'TotalPrice': 49.04}
# {'TransactionNo': '580694', 'CustomerNo': '16600', 'TotalPrice': 49.04}
# {'TransactionNo': '580694', 'CustomerNo': '16600', 'TotalPrice': 294.24}
# {'TransactionNo': '580694', 'CustomerNo': '16600', 'TotalPrice': 36.78}
# {'TransactionNo': '580694', 'CustomerNo': '16600', 'TotalPrice': 24.52}
# {'TransactionNo': '580694', 'CustomerNo': '16600', 'TotalPrice': 147.12}
# {'TransactionNo': '580694', 'CustomerNo': '16600', 'TotalPrice': 147.12}
# {'TransactionNo': '580694', 'CustomerNo': '16600', 'TotalPrice': 73.56}
# {'TransactionNo': '580694', 'CustomerNo': '16600', 'TotalPrice': 86.88}
# {'TransactionNo': '580694', 'CustomerNo': '16600', 'TotalPrice': 43.44}
# {'TransactionNo': '580694', 'CustomerNo': '16600', 'TotalPrice': 86.88}
# {'TransactionNo': '580694', 'CustomerNo': '16600', 'TotalPrice': 86.88}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 7.24}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 7.24}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 7.24}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 7.24}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 43.44}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 43.44}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 7.24}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 14.48}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 7.24}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 7.24}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 7.24}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 7.24}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 7.24}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 14.48}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 7.67}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 7.24}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 7.24}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 14.48}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 14.48}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 14.48}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 14.48}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 14.48}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 14.48}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 14.48}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 14.48}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 7.24}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 7.24}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 7.24}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 21.72}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 14.48}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 7.24}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 14.48}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 7.24}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 7.24}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 14.48}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 14.48}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 14.48}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 7.24}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 7.24}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 14.48}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 7.24}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 7.24}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 7.24}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 21.72}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 6.13}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 12.26}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 6.13}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 12.26}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 18.39}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 12.26}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 11.94}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 11.94}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 11.94}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 18.39}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 12.26}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 6.13}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 6.13}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 6.13}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 18.39}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 6.13}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 6.13}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 6.13}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 18.39}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 6.13}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 6.13}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 73.56}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 6.13}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 6.13}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 6.13}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 6.13}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 18.39}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 12.26}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 12.26}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 24.52}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 24.52}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 24.52}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 6.13}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 73.56}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 24.52}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 6.13}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 6.13}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 6.13}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 6.13}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 6.13}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 6.13}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 18.39}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 12.26}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 6.13}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 12.26}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 24.52}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 12.26}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 36.78}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 12.26}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 7.24}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 12.26}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 6.13}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 18.39}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 12.26}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 12.26}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 6.13}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 12.26}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 6.13}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 6.13}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 24.52}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 12.26}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 6.13}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 6.13}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 12.26}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 6.13}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 12.26}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 12.26}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 6.13}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 14.48}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 14.48}
# {'TransactionNo': '580695', 'CustomerNo': '13230', 'TotalPrice': 12.26}
# {'TransactionNo': '580696', 'CustomerNo': '17757', 'TotalPrice': 61.3}
# {'TransactionNo': '580696', 'CustomerNo': '17757', 'TotalPrice': 24.52}
# {'TransactionNo': '580696', 'CustomerNo': '17757', 'TotalPrice': 61.3}
# {'TransactionNo': '580696', 'CustomerNo': '17757', 'TotalPrice': 5.13}
# {'TransactionNo': '580696', 'CustomerNo': '17757', 'TotalPrice': 7.67}
# {'TransactionNo': '580696', 'CustomerNo': '17757', 'TotalPrice': 7.24}
# {'TransactionNo': '580696', 'CustomerNo': '17757', 'TotalPrice': 7.24}
# {'TransactionNo': '580696', 'CustomerNo': '17757', 'TotalPrice': 7.24}
# {'TransactionNo': '580696', 'CustomerNo': '17757', 'TotalPrice': 28.96}
# {'TransactionNo': '580696', 'CustomerNo': '17757', 'TotalPrice': 7.24}
# {'TransactionNo': '580696', 'CustomerNo': '17757', 'TotalPrice': 14.48}
# {'TransactionNo': '580696', 'CustomerNo': '17757', 'TotalPrice': 14.48}
# {'TransactionNo': '580696', 'CustomerNo': '17757', 'TotalPrice': 14.48}
# {'TransactionNo': '580696', 'CustomerNo': '17757', 'TotalPrice': 14.48}
# {'TransactionNo': '580696', 'CustomerNo': '17757', 'TotalPrice': 14.48}
# {'TransactionNo': '580696', 'CustomerNo': '17757', 'TotalPrice': 14.48}
# {'TransactionNo': '580696', 'CustomerNo': '17757', 'TotalPrice': 7.24}
# {'TransactionNo': '580696', 'CustomerNo': '17757', 'TotalPrice': 14.48}
# {'TransactionNo': '580696', 'CustomerNo': '17757', 'TotalPrice': 28.96}
# {'TransactionNo': '580696', 'CustomerNo': '17757', 'TotalPrice': 289.6}
# {'TransactionNo': '580697', 'CustomerNo': '15984', 'TotalPrice': 7.24}
# {'TransactionNo': '580697', 'CustomerNo': '15984', 'TotalPrice': 36.2}
# {'TransactionNo': '580697', 'CustomerNo': '15984', 'TotalPrice': 7.24}
# {'TransactionNo': '580697', 'CustomerNo': '15984', 'TotalPrice': 86.88}
# {'TransactionNo': '580697', 'CustomerNo': '15984', 'TotalPrice': 86.88}
# {'TransactionNo': '580697', 'CustomerNo': '15984', 'TotalPrice': 28.96}
# {'TransactionNo': '580697', 'CustomerNo': '15984', 'TotalPrice': 86.88}
# {'TransactionNo': '580697', 'CustomerNo': '15984', 'TotalPrice': 43.44}
# {'TransactionNo': '580697', 'CustomerNo': '15984', 'TotalPrice': 43.44}
# {'TransactionNo': '580697', 'CustomerNo': '15984', 'TotalPrice': 91.95}
# {'TransactionNo': '580697', 'CustomerNo': '15984', 'TotalPrice': 24.52}
# {'TransactionNo': '580697', 'CustomerNo': '15984', 'TotalPrice': 91.95}
# {'TransactionNo': '580697', 'CustomerNo': '15984', 'TotalPrice': 11.94}
# {'TransactionNo': '580697', 'CustomerNo': '15984', 'TotalPrice': 35.82}
# {'TransactionNo': '580697', 'CustomerNo': '15984', 'TotalPrice': 71.64}
# {'TransactionNo': '580697', 'CustomerNo': '15984', 'TotalPrice': 5.97}
# {'TransactionNo': '580697', 'CustomerNo': '15984', 'TotalPrice': 29.85}
# {'TransactionNo': '580697', 'CustomerNo': '15984', 'TotalPrice': 53.73}
# {'TransactionNo': '580697', 'CustomerNo': '15984', 'TotalPrice': 5.97}
# {'TransactionNo': '580697', 'CustomerNo': '15984', 'TotalPrice': 17.91}
# {'TransactionNo': '580697', 'CustomerNo': '15984', 'TotalPrice': 5.97}
# {'TransactionNo': '580697', 'CustomerNo': '15984', 'TotalPrice': 6.13}
# {'TransactionNo': '580697', 'CustomerNo': '15984', 'TotalPrice': 6.13}
# {'TransactionNo': '580697', 'CustomerNo': '15984', 'TotalPrice': 18.39}
# {'TransactionNo': '580697', 'CustomerNo': '15984', 'TotalPrice': 18.39}
# {'TransactionNo': '580697', 'CustomerNo': '15984', 'TotalPrice': 6.13}
# {'TransactionNo': '580697', 'CustomerNo': '15984', 'TotalPrice': 5.97}
# {'TransactionNo': '580697', 'CustomerNo': '15984', 'TotalPrice': 11.94}
# {'TransactionNo': '580697', 'CustomerNo': '15984', 'TotalPrice': 5.97}
# {'TransactionNo': '580697', 'CustomerNo': '15984', 'TotalPrice': 29.85}
# {'TransactionNo': '580697', 'CustomerNo': '15984', 'TotalPrice': 29.85}
# {'TransactionNo': '580697', 'CustomerNo': '15984', 'TotalPrice': 29.85}
# {'TransactionNo': '580697', 'CustomerNo': '15984', 'TotalPrice': 5.97}
# {'TransactionNo': '580697', 'CustomerNo': '15984', 'TotalPrice': 5.97}
# {'TransactionNo': '580697', 'CustomerNo': '15984', 'TotalPrice': 59.7}
# {'TransactionNo': '580697', 'CustomerNo': '15984', 'TotalPrice': 23.88}
# {'TransactionNo': '580697', 'CustomerNo': '15984', 'TotalPrice': 11.94}
# {'TransactionNo': '580697', 'CustomerNo': '15984', 'TotalPrice': 5.97}
# {'TransactionNo': '580697', 'CustomerNo': '15984', 'TotalPrice': 43.44}
# {'TransactionNo': '580697', 'CustomerNo': '15984', 'TotalPrice': 21.72}
# {'TransactionNo': '580697', 'CustomerNo': '15984', 'TotalPrice': 28.96}
# {'TransactionNo': '580697', 'CustomerNo': '15984', 'TotalPrice': 14.48}
# {'TransactionNo': '580697', 'CustomerNo': '15984', 'TotalPrice': 14.48}
# {'TransactionNo': '580697', 'CustomerNo': '15984', 'TotalPrice': 1448.0}
# {'TransactionNo': '580699', 'CustomerNo': '17699', 'TotalPrice': 7.24}
# {'TransactionNo': '580699', 'CustomerNo': '17699', 'TotalPrice': 7.24}
# {'TransactionNo': '580700', 'CustomerNo': '14219', 'TotalPrice': 14.48}
# {'TransactionNo': '580700', 'CustomerNo': '14219', 'TotalPrice': 173.76}
# {'TransactionNo': '580700', 'CustomerNo': '14219', 'TotalPrice': 28.96}
# {'TransactionNo': '580700', 'CustomerNo': '14219', 'TotalPrice': 86.88}
# {'TransactionNo': '580700', 'CustomerNo': '14219', 'TotalPrice': 86.88}
# {'TransactionNo': '580700', 'CustomerNo': '14219', 'TotalPrice': 86.88}
# {'TransactionNo': '580700', 'CustomerNo': '14219', 'TotalPrice': 86.88}
# {'TransactionNo': '580704', 'CustomerNo': '17404', 'TotalPrice': 289.6}
# {'TransactionNo': '580705', 'CustomerNo': '12683', 'TotalPrice': 86.88}
# {'TransactionNo': '580705', 'CustomerNo': '12683', 'TotalPrice': 173.76}
# {'TransactionNo': '580705', 'CustomerNo': '12683', 'TotalPrice': 86.88}
# {'TransactionNo': '580705', 'CustomerNo': '12683', 'TotalPrice': 86.88}
# {'TransactionNo': '580705', 'CustomerNo': '12683', 'TotalPrice': 86.88}
# {'TransactionNo': '580705', 'CustomerNo': '12683', 'TotalPrice': 28.96}
# {'TransactionNo': '580705', 'CustomerNo': '12683', 'TotalPrice': 24.52}
# {'TransactionNo': '580705', 'CustomerNo': '12683', 'TotalPrice': 24.52}
# {'TransactionNo': '580705', 'CustomerNo': '12683', 'TotalPrice': 36.78}
# {'TransactionNo': '580705', 'CustomerNo': '12683', 'TotalPrice': 24.52}
# {'TransactionNo': '580705', 'CustomerNo': '12683', 'TotalPrice': 36.78}
# {'TransactionNo': '580705', 'CustomerNo': '12683', 'TotalPrice': 61.3}
# {'TransactionNo': '580705', 'CustomerNo': '12683', 'TotalPrice': 35.82}
# {'TransactionNo': '580705', 'CustomerNo': '12683', 'TotalPrice': 11.94}
# {'TransactionNo': '580705', 'CustomerNo': '12683', 'TotalPrice': 12.26}
# {'TransactionNo': '580705', 'CustomerNo': '12683', 'TotalPrice': 12.26}
# {'TransactionNo': '580705', 'CustomerNo': '12683', 'TotalPrice': 12.26}
# {'TransactionNo': '580705', 'CustomerNo': '12683', 'TotalPrice': 73.56}
# {'TransactionNo': '580705', 'CustomerNo': '12683', 'TotalPrice': 73.56}
# {'TransactionNo': '580705', 'CustomerNo': '12683', 'TotalPrice': 73.56}
# {'TransactionNo': '580705', 'CustomerNo': '12683', 'TotalPrice': 73.56}
# {'TransactionNo': '580705', 'CustomerNo': '12683', 'TotalPrice': 73.56}
# {'TransactionNo': '580705', 'CustomerNo': '12683', 'TotalPrice': 147.12}
# {'TransactionNo': '580705', 'CustomerNo': '12683', 'TotalPrice': 613.0}
# {'TransactionNo': '580705', 'CustomerNo': '12683', 'TotalPrice': 147.12}
# {'TransactionNo': '580705', 'CustomerNo': '12683', 'TotalPrice': 245.2}
# {'TransactionNo': '580705', 'CustomerNo': '12683', 'TotalPrice': 49.04}
# {'TransactionNo': '580705', 'CustomerNo': '12683', 'TotalPrice': 49.04}
# {'TransactionNo': '580705', 'CustomerNo': '12683', 'TotalPrice': 36.78}
# {'TransactionNo': '580705', 'CustomerNo': '12683', 'TotalPrice': 191.75}
# {'TransactionNo': '580705', 'CustomerNo': '12683', 'TotalPrice': 86.88}
# {'TransactionNo': '580705', 'CustomerNo': '12683', 'TotalPrice': 86.88}
# {'TransactionNo': '580705', 'CustomerNo': '12683', 'TotalPrice': 173.76}
# {'TransactionNo': '580709', 'CustomerNo': '12709', 'TotalPrice': 6.39}
# {'TransactionNo': '580709', 'CustomerNo': '12709', 'TotalPrice': 7.24}
# {'TransactionNo': '580712', 'CustomerNo': '13021', 'TotalPrice': 28.96}
# {'TransactionNo': '580712', 'CustomerNo': '13021', 'TotalPrice': 21.72}
# {'TransactionNo': '580712', 'CustomerNo': '13021', 'TotalPrice': 86.88}
# {'TransactionNo': '580712', 'CustomerNo': '13021', 'TotalPrice': 28.96}
# {'TransactionNo': '580712', 'CustomerNo': '13021', 'TotalPrice': 173.76}
# {'TransactionNo': '580712', 'CustomerNo': '13021', 'TotalPrice': 14.48}
# {'TransactionNo': '580712', 'CustomerNo': '13021', 'TotalPrice': 14.48}
# {'TransactionNo': '580712', 'CustomerNo': '13021', 'TotalPrice': 14.48}
# {'TransactionNo': '580712', 'CustomerNo': '13021', 'TotalPrice': 14.48}
# {'TransactionNo': '580712', 'CustomerNo': '13021', 'TotalPrice': 43.44}
# {'TransactionNo': '580712', 'CustomerNo': '13021', 'TotalPrice': 86.88}
# {'TransactionNo': '580712', 'CustomerNo': '13021', 'TotalPrice': 86.88}
# {'TransactionNo': '580712', 'CustomerNo': '13021', 'TotalPrice': 86.88}
# {'TransactionNo': '580712', 'CustomerNo': '13021', 'TotalPrice': 181.0}
# {'TransactionNo': '580712', 'CustomerNo': '13021', 'TotalPrice': 86.88}
# {'TransactionNo': '580713', 'CustomerNo': '18030', 'TotalPrice': 28.96}
# {'TransactionNo': '580713', 'CustomerNo': '18030', 'TotalPrice': 7.24}
# {'TransactionNo': '580713', 'CustomerNo': '18030', 'TotalPrice': 7.24}
# {'TransactionNo': '580713', 'CustomerNo': '18030', 'TotalPrice': 86.88}
# {'TransactionNo': '580713', 'CustomerNo': '18030', 'TotalPrice': 21.72}
# {'TransactionNo': '580715', 'CustomerNo': '12715', 'TotalPrice': 30.65}
# {'TransactionNo': '580716', 'CustomerNo': '12367', 'TotalPrice': 86.88}
# {'TransactionNo': '580716', 'CustomerNo': '12367', 'TotalPrice': 434.4}
# {'TransactionNo': '580716', 'CustomerNo': '12367', 'TotalPrice': 43.44}
# {'TransactionNo': '580716', 'CustomerNo': '12367', 'TotalPrice': 43.44}
# {'TransactionNo': '580716', 'CustomerNo': '12367', 'TotalPrice': 14.48}
# {'TransactionNo': '580716', 'CustomerNo': '12367', 'TotalPrice': 86.88}
# {'TransactionNo': '580716', 'CustomerNo': '12367', 'TotalPrice': 86.88}
# {'TransactionNo': '580716', 'CustomerNo': '12367', 'TotalPrice': 86.88}
# {'TransactionNo': '580716', 'CustomerNo': '12367', 'TotalPrice': 181.0}
# {'TransactionNo': '580716', 'CustomerNo': '12367', 'TotalPrice': 181.0}
# {'TransactionNo': '580717', 'CustomerNo': '14608', 'TotalPrice': 57.92}
# {'TransactionNo': '580717', 'CustomerNo': '14608', 'TotalPrice': 347.52}
# {'TransactionNo': '580717', 'CustomerNo': '14608', 'TotalPrice': 86.88}
# {'TransactionNo': '580717', 'CustomerNo': '14608', 'TotalPrice': 173.76}
# {'TransactionNo': '580717', 'CustomerNo': '14608', 'TotalPrice': 65.16}
# {'TransactionNo': '580717', 'CustomerNo': '14608', 'TotalPrice': 173.76}
# {'TransactionNo': '580718', 'CustomerNo': '13079', 'TotalPrice': 173.76}
# {'TransactionNo': '580719', 'CustomerNo': '14739', 'TotalPrice': 521.28}
# {'TransactionNo': '580719', 'CustomerNo': '14739', 'TotalPrice': 260.64}
# {'TransactionNo': '580719', 'CustomerNo': '14739', 'TotalPrice': 289.6}
# {'TransactionNo': '580719', 'CustomerNo': '14739', 'TotalPrice': 289.6}
# {'TransactionNo': '580719', 'CustomerNo': '14739', 'TotalPrice': 238.8}
# {'TransactionNo': '580719', 'CustomerNo': '14739', 'TotalPrice': 220.68}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 6.13}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 12.26}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 6.13}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 6.13}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 12.26}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 36.78}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 6.13}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 6.13}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 6.13}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 12.26}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 12.26}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 24.52}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 12.26}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 12.26}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 36.78}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 36.78}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 6.13}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 6.13}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 12.26}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 36.78}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 12.26}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 6.13}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 5.97}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 6.13}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 6.13}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 12.26}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 18.39}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 18.39}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 6.13}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 12.26}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 24.52}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 30.68}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 14.48}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 86.88}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 14.48}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 14.48}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 11.94}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 5.97}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 12.26}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 12.26}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 12.26}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 6.13}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 6.13}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 6.13}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 6.13}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 6.13}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 12.26}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 24.52}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 6.13}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 6.13}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 12.26}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 36.78}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 24.52}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 24.52}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 12.26}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 12.26}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 6.13}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 12.26}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 12.26}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 12.26}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 12.26}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 12.26}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 12.26}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 6.13}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 6.13}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 7.24}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 86.88}
# {'TransactionNo': '580720', 'CustomerNo': '14629', 'TotalPrice': 12.26}
# {'TransactionNo': '580721', 'CustomerNo': '15274', 'TotalPrice': 73.56}
# {'TransactionNo': '580721', 'CustomerNo': '15274', 'TotalPrice': 147.12}
# {'TransactionNo': '580721', 'CustomerNo': '15274', 'TotalPrice': 147.12}
# {'TransactionNo': '580721', 'CustomerNo': '15274', 'TotalPrice': 61.3}
# {'TransactionNo': '580721', 'CustomerNo': '15274', 'TotalPrice': 24.52}
# {'TransactionNo': '580721', 'CustomerNo': '15274', 'TotalPrice': 24.52}
# {'TransactionNo': '580721', 'CustomerNo': '15274', 'TotalPrice': 18.39}
# {'TransactionNo': '580721', 'CustomerNo': '15274', 'TotalPrice': 73.56}
# {'TransactionNo': '580721', 'CustomerNo': '15274', 'TotalPrice': 73.56}
# {'TransactionNo': '580721', 'CustomerNo': '15274', 'TotalPrice': 24.52}
# {'TransactionNo': '580721', 'CustomerNo': '15274', 'TotalPrice': 17.91}
# {'TransactionNo': '580721', 'CustomerNo': '15274', 'TotalPrice': 36.78}
# {'TransactionNo': '580721', 'CustomerNo': '15274', 'TotalPrice': 73.56}
# {'TransactionNo': '580721', 'CustomerNo': '15274', 'TotalPrice': 36.78}
# {'TransactionNo': '580721', 'CustomerNo': '15274', 'TotalPrice': 147.12}
# {'TransactionNo': '580721', 'CustomerNo': '15274', 'TotalPrice': 73.56}
# {'TransactionNo': '580721', 'CustomerNo': '15274', 'TotalPrice': 86.88}
# {'TransactionNo': '580721', 'CustomerNo': '15274', 'TotalPrice': 173.76}
# {'TransactionNo': '580721', 'CustomerNo': '15274', 'TotalPrice': 86.88}
# {'TransactionNo': '580721', 'CustomerNo': '15274', 'TotalPrice': 86.88}
# {'TransactionNo': '580721', 'CustomerNo': '15274', 'TotalPrice': 28.96}
# {'TransactionNo': '580721', 'CustomerNo': '15274', 'TotalPrice': 36.78}
# {'TransactionNo': '580722', 'CustomerNo': '13985', 'TotalPrice': 147.12}
# {'TransactionNo': '580722', 'CustomerNo': '13985', 'TotalPrice': 122.6}
# {'TransactionNo': '580722', 'CustomerNo': '13985', 'TotalPrice': 61.3}
# {'TransactionNo': '580722', 'CustomerNo': '13985', 'TotalPrice': 61.3}
# {'TransactionNo': '580722', 'CustomerNo': '13985', 'TotalPrice': 61.3}
# {'TransactionNo': '580723', 'CustomerNo': '15856', 'TotalPrice': 24.52}
# {'TransactionNo': '580723', 'CustomerNo': '15856', 'TotalPrice': 6.13}
# {'TransactionNo': '580723', 'CustomerNo': '15856', 'TotalPrice': 18.39}
# {'TransactionNo': '580723', 'CustomerNo': '15856', 'TotalPrice': 18.39}
# {'TransactionNo': '580723', 'CustomerNo': '15856', 'TotalPrice': 18.39}
# {'TransactionNo': '580723', 'CustomerNo': '15856', 'TotalPrice': 153.25}
# {'TransactionNo': '580723', 'CustomerNo': '15856', 'TotalPrice': 153.25}
# {'TransactionNo': '580723', 'CustomerNo': '15856', 'TotalPrice': 294.24}
# {'TransactionNo': '580723', 'CustomerNo': '15856', 'TotalPrice': 166.0}
# {'TransactionNo': '580723', 'CustomerNo': '15856', 'TotalPrice': 36.78}
# {'TransactionNo': '580723', 'CustomerNo': '15856', 'TotalPrice': 73.56}
# {'TransactionNo': '580723', 'CustomerNo': '15856', 'TotalPrice': 73.56}
# {'TransactionNo': '580723', 'CustomerNo': '15856', 'TotalPrice': 147.12}
# {'TransactionNo': '580723', 'CustomerNo': '15856', 'TotalPrice': 73.56}
# {'TransactionNo': '580723', 'CustomerNo': '15856', 'TotalPrice': 49.04}
# {'TransactionNo': '580723', 'CustomerNo': '15856', 'TotalPrice': 6.13}
# {'TransactionNo': '580723', 'CustomerNo': '15856', 'TotalPrice': 49.04}
# {'TransactionNo': '580723', 'CustomerNo': '15856', 'TotalPrice': 24.52}
# {'TransactionNo': '580723', 'CustomerNo': '15856', 'TotalPrice': 24.52}
# {'TransactionNo': '580723', 'CustomerNo': '15856', 'TotalPrice': 24.52}
# {'TransactionNo': '580723', 'CustomerNo': '15856', 'TotalPrice': 153.25}
# {'TransactionNo': '580723', 'CustomerNo': '15856', 'TotalPrice': 153.25}
# {'TransactionNo': '580723', 'CustomerNo': '15856', 'TotalPrice': 153.25}
# {'TransactionNo': '580723', 'CustomerNo': '15856', 'TotalPrice': 24.52}
# {'TransactionNo': '580723', 'CustomerNo': '15856', 'TotalPrice': 67.43}
# {'TransactionNo': '580723', 'CustomerNo': '15856', 'TotalPrice': 24.52}
# {'TransactionNo': '580723', 'CustomerNo': '15856', 'TotalPrice': 36.78}
# {'TransactionNo': '580723', 'CustomerNo': '15856', 'TotalPrice': 73.56}
# {'TransactionNo': '580723', 'CustomerNo': '15856', 'TotalPrice': 73.56}
# {'TransactionNo': '580723', 'CustomerNo': '15856', 'TotalPrice': 245.2}
# {'TransactionNo': '580723', 'CustomerNo': '15856', 'TotalPrice': 30.65}
# {'TransactionNo': '580723', 'CustomerNo': '15856', 'TotalPrice': 18.39}
# {'TransactionNo': '580723', 'CustomerNo': '15856', 'TotalPrice': 18.39}
# {'TransactionNo': '580724', 'CustomerNo': '15724', 'TotalPrice': 6.13}
# {'TransactionNo': '580724', 'CustomerNo': '15724', 'TotalPrice': 5.97}
# {'TransactionNo': '580725', 'CustomerNo': '15932', 'TotalPrice': 220.68}
# {'TransactionNo': '580725', 'CustomerNo': '15932', 'TotalPrice': 147.12}
# {'TransactionNo': '580725', 'CustomerNo': '15932', 'TotalPrice': 73.56}
# {'TransactionNo': '580725', 'CustomerNo': '15932', 'TotalPrice': 196.16}
# {'TransactionNo': '580725', 'CustomerNo': '15932', 'TotalPrice': 147.12}
# {'TransactionNo': '580725', 'CustomerNo': '15932', 'TotalPrice': 147.12}
# {'TransactionNo': '580725', 'CustomerNo': '15932', 'TotalPrice': 49.04}
# {'TransactionNo': '580725', 'CustomerNo': '15932', 'TotalPrice': 147.12}
# {'TransactionNo': '580725', 'CustomerNo': '15932', 'TotalPrice': 147.12}
# {'TransactionNo': '580725', 'CustomerNo': '15932', 'TotalPrice': 147.12}
# {'TransactionNo': '580725', 'CustomerNo': '15932', 'TotalPrice': 36.78}
# {'TransactionNo': '580725', 'CustomerNo': '15932', 'TotalPrice': 122.6}
# {'TransactionNo': '580725', 'CustomerNo': '15932', 'TotalPrice': 73.56}
# {'TransactionNo': '580725', 'CustomerNo': '15932', 'TotalPrice': 73.56}
# {'TransactionNo': '580725', 'CustomerNo': '15932', 'TotalPrice': 86.88}
# {'TransactionNo': '580725', 'CustomerNo': '15932', 'TotalPrice': 173.76}
# {'TransactionNo': '580725', 'CustomerNo': '15932', 'TotalPrice': 147.12}
# {'TransactionNo': '580725', 'CustomerNo': '15932', 'TotalPrice': 122.6}
# {'TransactionNo': '580725', 'CustomerNo': '15932', 'TotalPrice': 49.04}
# {'TransactionNo': '580725', 'CustomerNo': '15932', 'TotalPrice': 147.12}
# {'TransactionNo': '580727', 'CustomerNo': '14096', 'TotalPrice': 12.26}
# {'TransactionNo': '580727', 'CustomerNo': '14096', 'TotalPrice': 61.3}
# {'TransactionNo': '580727', 'CustomerNo': '14096', 'TotalPrice': 18.39}
# {'TransactionNo': '580727', 'CustomerNo': '14096', 'TotalPrice': 6.64}
# {'TransactionNo': '580727', 'CustomerNo': '14096', 'TotalPrice': 6.13}
# {'TransactionNo': '580727', 'CustomerNo': '14096', 'TotalPrice': 24.52}
# {'TransactionNo': '580727', 'CustomerNo': '14096', 'TotalPrice': 6.13}
# {'TransactionNo': '580727', 'CustomerNo': '14096', 'TotalPrice': 6.13}
# {'TransactionNo': '580727', 'CustomerNo': '14096', 'TotalPrice': 6.13}
# {'TransactionNo': '580727', 'CustomerNo': '14096', 'TotalPrice': 6.13}
# {'TransactionNo': '580727', 'CustomerNo': '14096', 'TotalPrice': 12.26}
# {'TransactionNo': '580727', 'CustomerNo': '14096', 'TotalPrice': 6.13}
# {'TransactionNo': '580727', 'CustomerNo': '14096', 'TotalPrice': 6.64}
# {'TransactionNo': '580727', 'CustomerNo': '14096', 'TotalPrice': 6.13}
# {'TransactionNo': '580727', 'CustomerNo': '14096', 'TotalPrice': 6.13}
# {'TransactionNo': '580727', 'CustomerNo': '14096', 'TotalPrice': 6.13}
# {'TransactionNo': '580727', 'CustomerNo': '14096', 'TotalPrice': 5.97}
# {'TransactionNo': '580727', 'CustomerNo': '14096', 'TotalPrice': 23.88}
# {'TransactionNo': '580727', 'CustomerNo': '14096', 'TotalPrice': 5.97}
# {'TransactionNo': '580727', 'CustomerNo': '14096', 'TotalPrice': 35.82}
# {'TransactionNo': '580727', 'CustomerNo': '14096', 'TotalPrice': 5.97}
# {'TransactionNo': '580727', 'CustomerNo': '14096', 'TotalPrice': 11.94}
# {'TransactionNo': '580727', 'CustomerNo': '14096', 'TotalPrice': 11.94}
# {'TransactionNo': '580727', 'CustomerNo': '14096', 'TotalPrice': 24.52}
# {'TransactionNo': '580727', 'CustomerNo': '14096', 'TotalPrice': 6.13}
# {'TransactionNo': '580727', 'CustomerNo': '14096', 'TotalPrice': 85.82}
# {'TransactionNo': '580727', 'CustomerNo': '14096', 'TotalPrice': 6.64}
# {'TransactionNo': '580727', 'CustomerNo': '14096', 'TotalPrice': 6.13}
# {'TransactionNo': '580727', 'CustomerNo': '14096', 'TotalPrice': 12.26}
# {'TransactionNo': '580727', 'CustomerNo': '14096', 'TotalPrice': 6.13}
# {'TransactionNo': '580727', 'CustomerNo': '14096', 'TotalPrice': 6.13}
# {'TransactionNo': '580727', 'CustomerNo': '14096', 'TotalPrice': 24.52}
# {'TransactionNo': '580727', 'CustomerNo': '14096', 'TotalPrice': 6.64}
# {'TransactionNo': '580727', 'CustomerNo': '14096', 'TotalPrice': 18.39}
# {'TransactionNo': '580727', 'CustomerNo': '14096', 'TotalPrice': 98.08}
# {'TransactionNo': '580727', 'CustomerNo': '14096', 'TotalPrice': 6.13}
# {'TransactionNo': '580727', 'CustomerNo': '14096', 'TotalPrice': 7.67}
# {'TransactionNo': '580727', 'CustomerNo': '14096', 'TotalPrice': 7.24}
# ...
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 6.19}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 6.19}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 12.38}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 30.2}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 6.04}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 12.08}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 6.19}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 6.19}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 6.19}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 6.19}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 6.19}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 6.19}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 6.19}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 6.19}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 12.08}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 42.28}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 24.16}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 6.04}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 6.04}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 18.12}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 6.19}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 6.19}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 6.19}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 6.19}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 6.19}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 6.19}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 18.57}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 6.19}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 6.19}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 6.19}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 6.19}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 6.19}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 6.19}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 6.19}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 6.19}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 6.19}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 6.13}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 6.13}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 6.13}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 6.19}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 6.19}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 6.19}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 6.19}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 6.19}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 6.19}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 18.57}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 18.57}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 6.19}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 6.19}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 6.19}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 24.76}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 18.57}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 24.76}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 12.38}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 12.38}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 24.76}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 6.19}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 6.19}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 6.19}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 12.38}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 12.38}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 24.76}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 6.19}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 6.19}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 6.19}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 18.57}
# {'TransactionNo': '580148', 'CustomerNo': '14148', 'TotalPrice': 6.19}
# {'TransactionNo': '580149', 'CustomerNo': '12748', 'TotalPrice': 6.19}
# {'TransactionNo': '580150', 'CustomerNo': '16150', 'TotalPrice': 6.19}
# {'TransactionNo': '580150', 'CustomerNo': '16150', 'TotalPrice': 12.38}
# {'TransactionNo': '580151', 'CustomerNo': '17811', 'TotalPrice': 18.57}
# {'TransactionNo': '580151', 'CustomerNo': '17811', 'TotalPrice': 6.19}
# {'TransactionNo': '580151', 'CustomerNo': '17811', 'TotalPrice': 18.57}
# {'TransactionNo': '580151', 'CustomerNo': '17811', 'TotalPrice': 6.19}
# {'TransactionNo': '580151', 'CustomerNo': '17811', 'TotalPrice': 30.2}
# {'TransactionNo': '580151', 'CustomerNo': '17811', 'TotalPrice': 18.12}
# {'TransactionNo': '580151', 'CustomerNo': '17811', 'TotalPrice': 6.19}
# {'TransactionNo': '580151', 'CustomerNo': '17811', 'TotalPrice': 6.19}
# {'TransactionNo': '580151', 'CustomerNo': '17811', 'TotalPrice': 6.19}
# {'TransactionNo': '580151', 'CustomerNo': '17811', 'TotalPrice': 24.76}
# {'TransactionNo': '580151', 'CustomerNo': '17811', 'TotalPrice': 148.56}
# {'TransactionNo': '580151', 'CustomerNo': '17811', 'TotalPrice': 185.7}
# {'TransactionNo': '580152', 'CustomerNo': '12364', 'TotalPrice': 154.75}
# {'TransactionNo': '580152', 'CustomerNo': '12364', 'TotalPrice': 154.75}
# {'TransactionNo': '580152', 'CustomerNo': '12364', 'TotalPrice': 154.75}
# {'TransactionNo': '580152', 'CustomerNo': '12364', 'TotalPrice': 154.75}
# {'TransactionNo': '580152', 'CustomerNo': '12364', 'TotalPrice': 154.75}
# {'TransactionNo': '580152', 'CustomerNo': '12364', 'TotalPrice': 154.75}
# {'TransactionNo': '580152', 'CustomerNo': '12364', 'TotalPrice': 154.75}
# {'TransactionNo': '580152', 'CustomerNo': '12364', 'TotalPrice': 154.75}
# {'TransactionNo': '580152', 'CustomerNo': '12364', 'TotalPrice': 154.75}
# {'TransactionNo': '580152', 'CustomerNo': '12364', 'TotalPrice': 154.75}
# {'TransactionNo': '580152', 'CustomerNo': '12364', 'TotalPrice': 154.75}
# {'TransactionNo': '580152', 'CustomerNo': '12364', 'TotalPrice': 154.75}
# {'TransactionNo': '580152', 'CustomerNo': '12364', 'TotalPrice': 151.0}
# {'TransactionNo': '580152', 'CustomerNo': '12364', 'TotalPrice': 154.75}
# {'TransactionNo': '580152', 'CustomerNo': '12364', 'TotalPrice': 154.75}
# {'TransactionNo': '580152', 'CustomerNo': '12364', 'TotalPrice': 74.28}
# {'TransactionNo': '580152', 'CustomerNo': '12364', 'TotalPrice': 74.28}
# {'TransactionNo': '580152', 'CustomerNo': '12364', 'TotalPrice': 74.28}
# {'TransactionNo': '580152', 'CustomerNo': '12364', 'TotalPrice': 86.88}
# {'TransactionNo': '580152', 'CustomerNo': '12364', 'TotalPrice': 86.88}
# {'TransactionNo': '580152', 'CustomerNo': '12364', 'TotalPrice': 86.88}
# {'TransactionNo': '580152', 'CustomerNo': '12364', 'TotalPrice': 43.44}
# {'TransactionNo': '580152', 'CustomerNo': '12364', 'TotalPrice': 86.88}
# {'TransactionNo': '580152', 'CustomerNo': '12364', 'TotalPrice': 86.88}
# {'TransactionNo': '580152', 'CustomerNo': '12364', 'TotalPrice': 86.88}
# {'TransactionNo': '580152', 'CustomerNo': '12364', 'TotalPrice': 86.88}
# {'TransactionNo': '580153', 'CustomerNo': '12762', 'TotalPrice': 86.88}
# {'TransactionNo': '580153', 'CustomerNo': '12762', 'TotalPrice': 868.8}
# {'TransactionNo': '580153', 'CustomerNo': '12762', 'TotalPrice': 868.8}
# {'TransactionNo': '580153', 'CustomerNo': '12762', 'TotalPrice': 868.8}
# {'TransactionNo': '580153', 'CustomerNo': '12762', 'TotalPrice': 86.88}
# {'TransactionNo': '580153', 'CustomerNo': '12762', 'TotalPrice': 86.88}
# {'TransactionNo': '580153', 'CustomerNo': '12762', 'TotalPrice': 86.88}
# {'TransactionNo': '580153', 'CustomerNo': '12762', 'TotalPrice': 86.88}
# {'TransactionNo': '580153', 'CustomerNo': '12762', 'TotalPrice': 86.88}
# {'TransactionNo': '580153', 'CustomerNo': '12762', 'TotalPrice': 86.88}
# {'TransactionNo': '580153', 'CustomerNo': '12762', 'TotalPrice': 86.88}
# {'TransactionNo': '580153', 'CustomerNo': '12762', 'TotalPrice': 86.88}
# {'TransactionNo': '580153', 'CustomerNo': '12762', 'TotalPrice': 86.88}
# {'TransactionNo': '580153', 'CustomerNo': '12762', 'TotalPrice': 86.88}
# {'TransactionNo': '580153', 'CustomerNo': '12762', 'TotalPrice': 347.52}
# {'TransactionNo': '580153', 'CustomerNo': '12762', 'TotalPrice': 86.88}
# {'TransactionNo': '580153', 'CustomerNo': '12762', 'TotalPrice': 86.88}
# {'TransactionNo': '580153', 'CustomerNo': '12762', 'TotalPrice': 86.88}
# {'TransactionNo': '580153', 'CustomerNo': '12762', 'TotalPrice': 86.88}
# {'TransactionNo': '580153', 'CustomerNo': '12762', 'TotalPrice': 86.88}
# {'TransactionNo': '580153', 'CustomerNo': '12762', 'TotalPrice': 347.52}
# {'TransactionNo': '580153', 'CustomerNo': '12762', 'TotalPrice': 86.88}
# {'TransactionNo': '580153', 'CustomerNo': '12762', 'TotalPrice': 86.88}
# {'TransactionNo': '580153', 'CustomerNo': '12762', 'TotalPrice': 86.88}
# {'TransactionNo': '580153', 'CustomerNo': '12762', 'TotalPrice': 86.88}
# {'TransactionNo': '580153', 'CustomerNo': '12762', 'TotalPrice': 86.88}
# {'TransactionNo': '580153', 'CustomerNo': '12762', 'TotalPrice': 43.44}
# {'TransactionNo': '580153', 'CustomerNo': '12762', 'TotalPrice': 86.88}
# {'TransactionNo': '580153', 'CustomerNo': '12762', 'TotalPrice': 86.88}
# {'TransactionNo': '580153', 'CustomerNo': '12762', 'TotalPrice': 43.44}
# {'TransactionNo': '580153', 'CustomerNo': '12762', 'TotalPrice': 86.88}
# {'TransactionNo': '580153', 'CustomerNo': '12762', 'TotalPrice': 86.88}
# {'TransactionNo': '580153', 'CustomerNo': '12762', 'TotalPrice': 173.76}
# {'TransactionNo': '580153', 'CustomerNo': '12762', 'TotalPrice': 347.52}
# {'TransactionNo': '580153', 'CustomerNo': '12762', 'TotalPrice': 65.16}
# {'TransactionNo': '580153', 'CustomerNo': '12762', 'TotalPrice': 86.88}
# {'TransactionNo': '580153', 'CustomerNo': '12762', 'TotalPrice': 86.88}
# {'TransactionNo': '580153', 'CustomerNo': '12762', 'TotalPrice': 74.28}
# {'TransactionNo': '580153', 'CustomerNo': '12762', 'TotalPrice': 24.76}
# {'TransactionNo': '580153', 'CustomerNo': '12762', 'TotalPrice': 43.44}
# {'TransactionNo': '580153', 'CustomerNo': '12762', 'TotalPrice': 86.88}
# {'TransactionNo': '580153', 'CustomerNo': '12762', 'TotalPrice': 86.88}
# {'TransactionNo': '580153', 'CustomerNo': '12762', 'TotalPrice': 74.28}
# {'TransactionNo': '580153', 'CustomerNo': '12762', 'TotalPrice': 148.56}
# {'TransactionNo': '580153', 'CustomerNo': '12762', 'TotalPrice': 148.56}
# {'TransactionNo': '580153', 'CustomerNo': '12762', 'TotalPrice': 148.56}
# {'TransactionNo': '580153', 'CustomerNo': '12762', 'TotalPrice': 148.56}
# {'TransactionNo': '580154', 'CustomerNo': '12569', 'TotalPrice': 12.38}
# {'TransactionNo': '580154', 'CustomerNo': '12569', 'TotalPrice': 12.38}
# {'TransactionNo': '580154', 'CustomerNo': '12569', 'TotalPrice': 24.76}
# {'TransactionNo': '580155', 'CustomerNo': '13183', 'TotalPrice': 24.76}
# {'TransactionNo': '580155', 'CustomerNo': '13183', 'TotalPrice': 111.42}
# {'TransactionNo': '580155', 'CustomerNo': '13183', 'TotalPrice': 445.68}
# {'TransactionNo': '580155', 'CustomerNo': '13183', 'TotalPrice': 297.12}
# {'TransactionNo': '580155', 'CustomerNo': '13183', 'TotalPrice': 297.12}
# {'TransactionNo': '580155', 'CustomerNo': '13183', 'TotalPrice': 148.56}
# {'TransactionNo': '580156', 'CustomerNo': '14897', 'TotalPrice': 74.28}
# {'TransactionNo': '580156', 'CustomerNo': '14897', 'TotalPrice': 24.76}
# {'TransactionNo': '580156', 'CustomerNo': '14897', 'TotalPrice': 37.14}
# {'TransactionNo': '580156', 'CustomerNo': '14897', 'TotalPrice': 37.14}
# {'TransactionNo': '580156', 'CustomerNo': '14897', 'TotalPrice': 37.14}
# {'TransactionNo': '580156', 'CustomerNo': '14897', 'TotalPrice': 74.28}
# {'TransactionNo': '580156', 'CustomerNo': '14897', 'TotalPrice': 24.76}
# {'TransactionNo': '580156', 'CustomerNo': '14897', 'TotalPrice': 24.76}
# {'TransactionNo': '580156', 'CustomerNo': '14897', 'TotalPrice': 24.76}
# {'TransactionNo': '580156', 'CustomerNo': '14897', 'TotalPrice': 24.76}
# {'TransactionNo': '580156', 'CustomerNo': '14897', 'TotalPrice': 24.76}
# {'TransactionNo': '580156', 'CustomerNo': '14897', 'TotalPrice': 24.76}
# {'TransactionNo': '580156', 'CustomerNo': '14897', 'TotalPrice': 24.76}
# {'TransactionNo': '580156', 'CustomerNo': '14897', 'TotalPrice': 74.28}
# {'TransactionNo': '580156', 'CustomerNo': '14897', 'TotalPrice': 74.28}
# {'TransactionNo': '580156', 'CustomerNo': '14897', 'TotalPrice': 74.28}
# {'TransactionNo': '580156', 'CustomerNo': '14897', 'TotalPrice': 74.28}
# {'TransactionNo': '580156', 'CustomerNo': '14897', 'TotalPrice': 148.56}
# {'TransactionNo': '580157', 'CustomerNo': '14083', 'TotalPrice': 6.19}
# {'TransactionNo': '580157', 'CustomerNo': '14083', 'TotalPrice': 6.19}
# {'TransactionNo': '580157', 'CustomerNo': '14083', 'TotalPrice': 6.19}
# {'TransactionNo': '580157', 'CustomerNo': '14083', 'TotalPrice': 12.38}
# {'TransactionNo': '580157', 'CustomerNo': '14083', 'TotalPrice': 6.19}
# {'TransactionNo': '580157', 'CustomerNo': '14083', 'TotalPrice': 12.38}
# {'TransactionNo': '580157', 'CustomerNo': '14083', 'TotalPrice': 12.38}
# {'TransactionNo': '580158', 'CustomerNo': '12558', 'TotalPrice': 74.28}
# {'TransactionNo': '580158', 'CustomerNo': '12558', 'TotalPrice': 148.56}
# {'TransactionNo': '580158', 'CustomerNo': '12558', 'TotalPrice': 148.56}
# {'TransactionNo': '580158', 'CustomerNo': '12558', 'TotalPrice': 148.56}
# {'TransactionNo': '580158', 'CustomerNo': '12558', 'TotalPrice': 222.84}
# {'TransactionNo': '580158', 'CustomerNo': '12558', 'TotalPrice': 74.28}
# {'TransactionNo': '580158', 'CustomerNo': '12558', 'TotalPrice': 74.28}
# {'TransactionNo': '580158', 'CustomerNo': '12558', 'TotalPrice': 74.28}
# {'TransactionNo': '580158', 'CustomerNo': '12558', 'TotalPrice': 61.9}
# {'TransactionNo': '580158', 'CustomerNo': '12558', 'TotalPrice': 61.9}
# {'TransactionNo': '580158', 'CustomerNo': '12558', 'TotalPrice': 123.8}
# {'TransactionNo': '580159', 'CustomerNo': '17942', 'TotalPrice': 12.38}
# {'TransactionNo': '580159', 'CustomerNo': '17942', 'TotalPrice': 222.84}
# {'TransactionNo': '580160', 'CustomerNo': '12700', 'TotalPrice': 24.76}
# {'TransactionNo': '580160', 'CustomerNo': '12700', 'TotalPrice': 74.28}
# {'TransactionNo': '580160', 'CustomerNo': '12700', 'TotalPrice': 74.28}
# {'TransactionNo': '580160', 'CustomerNo': '12700', 'TotalPrice': 297.12}
# {'TransactionNo': '580160', 'CustomerNo': '12700', 'TotalPrice': 74.28}
# {'TransactionNo': '580160', 'CustomerNo': '12700', 'TotalPrice': 30.95}
# {'TransactionNo': '580160', 'CustomerNo': '12700', 'TotalPrice': 74.28}
# {'TransactionNo': '580160', 'CustomerNo': '12700', 'TotalPrice': 148.56}
# {'TransactionNo': '580160', 'CustomerNo': '12700', 'TotalPrice': 148.56}
# {'TransactionNo': '580160', 'CustomerNo': '12700', 'TotalPrice': 148.56}
# {'TransactionNo': '580160', 'CustomerNo': '12700', 'TotalPrice': 148.56}
# {'TransactionNo': '580160', 'CustomerNo': '12700', 'TotalPrice': 148.56}
# {'TransactionNo': '580160', 'CustomerNo': '12700', 'TotalPrice': 49.52}
# {'TransactionNo': '580160', 'CustomerNo': '12700', 'TotalPrice': 49.52}
# {'TransactionNo': '580160', 'CustomerNo': '12700', 'TotalPrice': 49.52}
# {'TransactionNo': '580160', 'CustomerNo': '12700', 'TotalPrice': 49.52}
# {'TransactionNo': '580160', 'CustomerNo': '12700', 'TotalPrice': 49.52}
# {'TransactionNo': '580160', 'CustomerNo': '12700', 'TotalPrice': 12.38}
# {'TransactionNo': '580160', 'CustomerNo': '12700', 'TotalPrice': 123.8}
# {'TransactionNo': '580160', 'CustomerNo': '12700', 'TotalPrice': 173.76}

# %%
pd.DataFrame(transformed_data)
# Out:
#       TransactionNo CustomerNo  TotalPrice
# 0            581482      17490      257.64
# 1            581475      13069      383.40
# 2            581475      13069      138.36
# 3            581475      13069      127.80
# 4            581475      13069       71.64
# ...             ...        ...         ...
# 19994        580160      12700       49.52
# 19995        580160      12700       49.52
# 19996        580160      12700       12.38
# 19997        580160      12700      123.80
# 19998        580160      12700      173.76
#
# [19999 rows x 3 columns]

# %%
pd.DataFrame(transformed_data).groupby("CustomerNo").mean()
# Out:
# <ipython-input-31-5865e4c4fcbf>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   pd.DataFrame(transformed_data).groupby("CustomerNo").mean()
#              TotalPrice
# CustomerNo
# 12256        106.348548
# 12347        110.198182
# 12358        148.560000
# 12362         46.976552
# 12364        122.766923
# ...                 ...
# 18237         65.543750
# 18272         68.359130
# 18273        120.800000
# 18283         17.570600
# na         -1671.300000
#
# [549 rows x 1 columns]

# %%
mean_data = pd.DataFrame(transformed_data).groupby("CustomerNo").mean()

# Sort Total price mean values in ascending order
sorted_data = mean_data.sort_values(by="TotalPrice", ascending=False)

print(sorted_data)
# Out:
#                TotalPrice
# CustomerNo
# 16446       250679.525000
# 15195         8690.760000
# 17949         8154.000000
# 16000         3514.544444
# 17857         2411.005000
# ...                   ...
# 17426          -74.280000
# 12967          -99.239231
# 16019         -103.992000
# 14298         -664.393333
# na           -1671.300000
#
# [549 rows x 1 columns]
# <ipython-input-33-70903a0264f2>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   mean_data = pd.DataFrame(transformed_data).groupby("CustomerNo").mean()

# %% [markdown]
# We get values with (-) since those are cancelled transactions...
#
# \
